# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshG1308/Data-Science-Models/blob/main/IPC_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -r './requirements.txt'
# Out:
# Collecting chromadb (from -r ./requirements.txt (line 1))
#   Downloading chromadb-0.4.10-py3-none-any.whl (422 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.4/422.4 kB 4.3 MB/s eta 0:00:00
# Collecting langchain (from -r ./requirements.txt (line 2))
#   Downloading langchain-0.0.293-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.4 MB/s eta 0:00:00
# Collecting sentence_transformers (from -r ./requirements.txt (line 3))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pypdf (from -r ./requirements.txt (line 4))
#   Downloading pypdf-3.16.1-py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.3/276.3 kB 10.6 MB/s eta 0:00:00
# Collecting textract (from -r ./requirements.txt (line 5))
#   Downloading textract-1.6.5-py3-none-any.whl (23 kB)
# Collecting openai (from -r ./requirements.txt (line 6))
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.8 MB/s eta 0:00:00
# Collecting tiktoken (from -r ./requirements.txt (line 7))
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.3 MB/s eta 0:00:00
# Collecting faiss-cpu (from -r ./requirements.txt (line 8))
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (1.10.12)
# Collecting chroma-hnswlib==0.7.3 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 52.5 MB/s eta 0:00:00
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.4 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.2 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 65.8 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 78.0 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.7 MB/s eta 0:00:00
# Collecting pypika>=0.48.9 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (6.0.1)
# Collecting bcrypt>=4.0.1 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r ./requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (2.0.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain->-r ./requirements.txt (line 2))
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.38 (from langchain->-r ./requirements.txt (line 2))
#   Downloading langsmith-0.0.38-py3-none-any.whl (38 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (2.8.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r ./requirements.txt (line 2)) (8.2.3)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers->-r ./requirements.txt (line 3))
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r ./requirements.txt (line 3)) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r ./requirements.txt (line 3)) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r ./requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r ./requirements.txt (line 3)) (1.11.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r ./requirements.txt (line 3)) (3.8.1)
# Collecting sentencepiece (from sentence_transformers->-r ./requirements.txt (line 3))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers->-r ./requirements.txt (line 3))
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 26.7 MB/s eta 0:00:00
# Collecting argcomplete~=1.10.0 (from textract->-r ./requirements.txt (line 5))
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0 (from textract->-r ./requirements.txt (line 5))
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 12.0 MB/s eta 0:00:00
# Collecting chardet==3.* (from textract->-r ./requirements.txt (line 5))
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 12.9 MB/s eta 0:00:00
# Collecting docx2txt~=0.8 (from textract->-r ./requirements.txt (line 5))
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting extract-msg<=0.29.* (from textract->-r ./requirements.txt (line 5))
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 5.4 MB/s eta 0:00:00
# Collecting pdfminer.six==20191110 (from textract->-r ./requirements.txt (line 5))
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 74.4 MB/s eta 0:00:00
# Collecting python-pptx~=0.6.18 (from textract->-r ./requirements.txt (line 5))
#   Downloading python_pptx-0.6.22-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 32.5 MB/s eta 0:00:00
# Collecting six~=1.12.0 (from textract->-r ./requirements.txt (line 5))
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1 (from textract->-r ./requirements.txt (line 5))
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 11.8 MB/s eta 0:00:00
# Collecting xlrd~=1.2.0 (from textract->-r ./requirements.txt (line 5))
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 10.0 MB/s eta 0:00:00
# Collecting pycryptodome (from pdfminer.six==20191110->textract->-r ./requirements.txt (line 5))
#   Downloading pycryptodome-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.6 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract->-r ./requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->-r ./requirements.txt (line 7)) (2023.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ./requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract->-r ./requirements.txt (line 5)) (2.5)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain->-r ./requirements.txt (line 2))
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain->-r ./requirements.txt (line 2))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting imapclient==2.1.0 (from extract-msg<=0.29.*->textract->-r ./requirements.txt (line 5))
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 7.0 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from extract-msg<=0.29.*->textract->-r ./requirements.txt (line 5))
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract->-r ./requirements.txt (line 5)) (5.0.1)
# Collecting compressed-rtf>=1.0.6 (from extract-msg<=0.29.*->textract->-r ./requirements.txt (line 5))
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic>=1.1.1 (from extract-msg<=0.29.*->textract->-r ./requirements.txt (line 5))
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 12.0 MB/s eta 0:00:00
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb->-r ./requirements.txt (line 1))
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers->-r ./requirements.txt (line 3)) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers->-r ./requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers->-r ./requirements.txt (line 3)) (23.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1)) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1)) (1.12)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->-r ./requirements.txt (line 1))
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->-r ./requirements.txt (line 1))
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pulsar-client>=3.1.0->chromadb->-r ./requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract->-r ./requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: Pillow<=9.5.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract->-r ./requirements.txt (line 5)) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx~=0.6.18->textract->-r ./requirements.txt (line 5))
#   Downloading XlsxWriter-3.1.4-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb->-r ./requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r ./requirements.txt (line 2)) (2.0.2)
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers->-r ./requirements.txt (line 3))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (16.0.6)
# Collecting tokenizers>=0.13.2 (from chromadb->-r ./requirements.txt (line 1))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers->-r ./requirements.txt (line 3))
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1)) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 30.1 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 76.2 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.2 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->-r ./requirements.txt (line 1))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers->-r ./requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers->-r ./requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb->-r ./requirements.txt (line 1)) (3.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain->-r ./requirements.txt (line 2))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers->-r ./requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb->-r ./requirements.txt (line 1)) (1.1.3)
# Building wheels for collected packages: sentence_transformers, docx2txt, pypika, compressed-rtf, olefile
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=5adade9b08d52c77f2fc1fcbf5b74510bd7ddc5e402ec1de5fa20273c6b7a9a9
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=95035d3b4e455a9e1fb1c814bbcc39ed58bbc4212331bdae859be9b8fce5baca
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=4538def15e2afa2d743f55f42a1ea33c3ca753d11384c3ff92c90495e9e0bf51
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6185 sha256=a822713de595d088f43a7f7a86a6fe1013f7ae95858dd3203d0678f7f87f7c18
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=3d4e36e1ab56b96d63feb05e3d155a38ca83b8014dd3512ca75b37d51e195fc0
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
# Successfully built sentence_transformers docx2txt pypika compressed-rtf olefile
# Installing collected packages: tokenizers, SpeechRecognition, sentencepiece, safetensors, pypika, monotonic, faiss-cpu, ebcdic, docx2txt, compressed-rtf, chardet, argcomplete, XlsxWriter, xlrd, websockets, uvloop, six, python-dotenv, pypdf, pycryptodome, pulsar-client, overrides, olefile, mypy-extensions, marshmallow, humanfriendly, httptools, h11, chroma-hnswlib, beautifulsoup4, bcrypt, backoff, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, python-pptx, pdfminer.six, langsmith, imapclient, huggingface-hub, coloredlogs, transformers, posthog, openai, onnxruntime, fastapi, extract-msg, dataclasses-json, textract, langchain, chromadb, sentence_transformers
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.6.3 requires six>=1.13.0, but you have six 1.12.0 which is incompatible.
# yfinance 0.2.28 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed SpeechRecognition-3.8.1 XlsxWriter-3.1.4 argcomplete-1.10.3 backoff-2.2.1 bcrypt-4.0.1 beautifulsoup4-4.8.2 chardet-3.0.4 chroma-hnswlib-0.7.3 chromadb-0.4.10 coloredlogs-15.0.1 compressed-rtf-1.0.6 dataclasses-json-0.5.14 docx2txt-0.8 ebcdic-1.1.1 extract-msg-0.28.7 faiss-cpu-1.7.4 fastapi-0.99.1 h11-0.14.0 httptools-0.6.0 huggingface-hub-0.16.4 humanfriendly-10.0 imapclient-2.1.0 langchain-0.0.293 langsmith-0.0.38 marshmallow-3.20.1 monotonic-1.6 mypy-extensions-1.0.0 olefile-0.46 onnxruntime-1.15.1 openai-0.28.0 overrides-7.4.0 pdfminer.six-20191110 posthog-3.0.2 pulsar-client-3.3.0 pycryptodome-3.19.0 pypdf-3.16.1 pypika-0.48.9 python-dotenv-1.0.0 python-pptx-0.6.22 safetensors-0.3.3 sentence_transformers-2.2.2 sentencepiece-0.1.99 six-1.12.0 starlette-0.27.0 textract-1.6.5 tiktoken-0.5.1 tokenizers-0.13.3 transformers-4.33.2 typing-inspect-0.9.0 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3 xlrd-1.2.0

# %%
import os
from transformers import GPT2TokenizerFast
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
from langchain.chains import ConversationalRetrievalChain

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
loader = PyPDFLoader("./ipc.pdf")
pages = loader.load_and_split()
print(pages[0])
chunks = pages
# Out:
# page_content='1 \n THE INDIAN PENAL CODE  \n______________  \nARRANGEMENT OF SECTIONS  \n_________________  \nCHAPTER I  \nINTRODUCTION  \nPREAMBLE  \nSECTIONS  \n1. Title and extent of operation of the Code.  \n2. Punishment of offences committed within India.  \n3. Punishment of offences committed beyond, but  which by law may be tried within, India.  \n4. Extension of Code to extra -territorial offences.  \n5. Certain laws not to be affected by this Act.  \nCHAPTER II  \nGENERAL  EXPLANATIONS  \n6. Definitions in the Code to be understood subject to exceptions.  \n7. Sense of expression once  explained.  \n8. Gender.  \n9. Number.  \n10. “Man”.  “Woman”.  \n11. “Person ”. \n12.  “Public”.  \n13. [Omitted .] \n14. “Servant of Government”.  \n15. [Repealed.]  \n16. [Repealed.]  \n17. “Government”.  \n18. “India”.  \n19. “Judge”.  \n20. “Court of Justice”.  \n21. “Public servant”.  \n22. “Moveable property”.  \n23. “Wrongful gain”.  \n“Wrongful loss”.  \nGainin g wrongfully / Losing  wrongfully.  \n24.  “Dishonestly”.  \n25. “Fraudulently”.  \n26. “Reason to believe”.  \n27. Property in posse ssion of wife, clerk or servant . \n28. “Counterfeit”.  \n29. “Document”.  \n29A. “Electronic record ”. \n30. “Valuable security”.  \n31. “A will”.  \n32. Words referring to acts include illegal omissions.  \n33. “Act”.  \n“Omission”.  \n34. Acts done by several persons in furtherance of common intention.  \n35. When such an act is criminal by reason of its being done with a criminal knowledge or intention.  \n36. Effect caused partly by act and partly by omission.  \n37. Co-operation by doing one of several acts constituting an offence.' metadata={'source': './ipc.pdf', 'page': 0}

# %%
# Step 1: Convert PDF to text
import textract
doc = textract.process("./ipc.pdf")

# Step 2: Save to .txt and reopen (helps prevent issues)
with open('ipc.txt', 'w') as f:
    f.write(doc.decode('utf-8'))

with open('ipc.txt', 'r') as f:
    text = f.read()

# Step 3: Create function to count tokens
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

def count_tokens(text: str) -> int:
    return len(tokenizer.encode(text))

# Step 4: Split text into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap  = 200,
    length_function = count_tokens,
)

chunks = text_splitter.create_documents([text])
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %%
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(chunks, embeddings)

# %%
chain = load_qa_chain(OpenAI(temperature=0), chain_type="stuff")

query = "porn"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' According to the context, Section 354A of the Indian Penal Code states that any man who commits physical contact and advances involving unwelcome and explicit sexual overtures, a demand or request for sexual favours, showing pornography against the will of a woman, or making sexually coloured remarks, shall be guilty of the offence of sexual harassment. Punishment for this offence is rigorous imprisonment for a term which may extend to three years, or with fine, or with both.'

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

# Load the QA model and initialize it
qa_model = load_qa_chain(OpenAI(temperature=0), chain_type="stuff")

@app.route('/qa', methods=['POST'])
def qa_endpoint():
    try:
        # Get the input query from the request
        data = request.get_json()
        query = data.get('query')

        # Perform document similarity search
        docs = db.similarity_search(query)

        # Run the QA model on the found documents
        answers = []
        for doc in docs:
            answer = qa_model.run(input_documents=doc, question=query)
            answers.append({"document": doc, "answer": answer})

        return jsonify({"answers": answers})

    except Exception as e:
        return jsonify({"error": str(e)}), 500

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
